# %% [markdown]
# # Exporting to CSV
# After collecting data in your program, it's often useful to save it in an external file for easier sharing and analysis. CSV (Comma-Separated Values) is a widely used format because it is simple, lightweight, and compatible with many applications, including spreadsheets and databases. You can read more about the format [here](https://docs.fileformat.com/spreadsheet/csv/).
#
# The following script demonstrates how to export data programmatically from an object into a CSV file.

# %%
import os
import pathlib

example_user_object = {
    "type": "user",
    "username": "JohnDoe123",
    "id": 1,
    "first_name": "John",
    "last_name": "Doe",
    "message_count": 23
}

example_message_object = {
    "type": "message",
    "sender": example_user_object,
    "content": "This is the message",
    "media": True,
    "media_download": "https://link_to_media.com/media?q=abcdefg"
}

example_object_list = [
    example_user_object,
    example_message_object
]

with open("example_users_csv.csv", "a") as users_file, open("example_messages_csv.csv", "a") as messages_file:

    #iterate through example list of objects
    for obj in example_object_list:

        #handle user objects
        if obj["type"] == "user":
            #if the file is empty, write the first row of labels
            if os.path.getsize("example_users_csv.csv") == 0:
                label_row = ""
                for key, value in obj.items():
                    label_row += key + ","
                label_row = label_row[:-1] + "\n"
                users_file.writelines(label_row)
                

            row = ""
            for key, value in obj.items():
                row += str(value) + ","
            row = row[:-1] + "\n"
            users_file.writelines(row)

        #handle message objects
        if obj["type"] == "message":
            #if the file is empty, write the first row of labels
            if os.path.getsize("example_messages_csv.csv") == 0:
                    label_row = ""
                    for key, value in obj.items():
                        if key == "sender":
                            label_row += "sender_id" + ","
                        else:
                            label_row += key + ","
                    label_row = label_row[:-1] + "\n"
                    messages_file.writelines(label_row)
                    

            row = ""
            for key, value in obj.items():
                if type(value) is dict:
                    row += str(value["id"]) + ","
                else:
                    row += str(value) + ","
            row = row[:-1] + "\n"
            messages_file.writelines(row)

#printing the contents of the files for demonstration purposes
print("messages file:")
with open("example_messages_csv.csv", "r") as file:
    for line in file:
        print(line, end="")

print("\nusers file:")
with open("example_users_csv.csv", "r") as file:
    for line in file:
        print(line, end="")

file_to_rem = pathlib.Path("example_users_csv.csv")
file_to_rem.unlink()
file_to_rem = pathlib.Path("example_messages_csv.csv")
file_to_rem.unlink()
# Out:
# messages file:
# type,sender_id,content,media,media_download
# message,1,This is the message,True,https://link_to_media.com/media?q=abcdefg
#
# users file:
# type,username,id,first_name,last_name,message_count
# user,JohnDoe123,1,John,Doe,23

# %% [markdown]
# The next script takes it a step further, getting the last 10 messages from the nytimes Telegram channel and writing its data to a csv file.

# %%
from dotenv import load_dotenv
from telethon import TelegramClient
import os
import pathlib
import datetime

load_dotenv()

TELEGRAM_API_ID = os.getenv("TELEGRAM_API_ID")
TELEGRAM_API_HASH = os.getenv("TELEGRAM_API_HASH")
PHONE_NUMBER = os.getenv("PHONE_NUMBER")

async with TelegramClient("simpatbos", TELEGRAM_API_ID, TELEGRAM_API_HASH) as client:
    channel_name = "nytimes"
    limit = 10
    with open("nytimes_posts.csv", "a") as file:
        written_labels = False
        async for message in client.iter_messages(channel_name, limit):
            message = message.to_dict()
            if not written_labels:
                label_row = ""
                for key in message.keys():
                    if key == "_":
                        label_row += "type,"
                    else:
                        label_row += key + ","
                label_row = label_row[:-1] + "\n"
                file.writelines(label_row)
                written_labels = True
                
    
            row = ""
            for value in message.values():
                if type(value) is not str and type(value) is not int and type(value) is not bool and type(value) is not list and value is not None:
                    if type(value) is datetime.datetime:
                        row += value.strftime("%Y-%m-%d %H:%M:%S")
                    else:
                        row += value["_"] + " Object"
                else:
                    row += str(value)
                    row = row.replace("\n", "\\n")
                    row = row.replace(",", ";")
                row += ","
            row = row[:-1] + "\n"
            file.writelines(row)

#printing the contents of the file for demonstration purposes
with open("nytimes_posts.csv", "r") as file:
    for line in file:
        print(line, end="")

file_to_rem = pathlib.Path("nytimes_posts.csv")
file_to_rem.unlink()
# Out:
# type,id,peer_id,date,message,out,mentioned,media_unread,silent,post,from_scheduled,legacy,edit_hide,pinned,noforwards,invert_media,offline,video_processing_pending,from_id,from_boosts_applied,saved_peer_id,fwd_from,via_bot_id,via_business_bot_id,reply_to,media,reply_markup,entities,views,forwards,replies,edit_date,post_author,grouped_id,reactions,restriction_reason,ttl_period,quick_reply_shortcut_id,effect,factcheck
# Message;3376;PeerChannel Object;2025-04-03 18:55:26;Here are some of the stories we are covering from around the world:\n\nThe War on Nature in Ukraine\n\nThe human costs of Russia’s war in Ukraine are enormous. But Ukraine’s environment is also being devastated. The war may end; but damage from artillery shells; mines; drones and missiles will endure for decades; experts say.\n\nWhere Trump’s Tariffs Will Hit Hardest\n\nThese countries are some of the most vulnerable to Washington’s sweeping new tariffs. Their economies are deeply reliant on selling goods to the United States; and many of them were hit with especially steep taxes.\n\nIsrael Hits Syria With New Strikes and Ground Raid as Tensions Soar\n\nSyria accused Israel on Thursday of trying to destabilize the country after intense airstrikes on military bases and a deadly raid in southern Syria.\n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 28; 'url': 'https://nyti.ms/4i3rrUC'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 28}; {'_': 'MessageEntityTextUrl'; 'offset': 325; 'length': 38; 'url': 'https://nyti.ms/42oVAIq'}; {'_': 'MessageEntityBold'; 'offset': 325; 'length': 38}; {'_': 'MessageEntityTextUrl'; 'offset': 581; 'length': 67; 'url': 'https://nyti.ms/4lfJ72d'}; {'_': 'MessageEntityBold'; 'offset': 581; 'length': 67}; {'_': 'MessageEntityMention'; 'offset': 801; 'length': 8}];2929;2;None;2025-04-03 18:57:56;None;None;MessageReactions Object;[];None;None;None;None
# Message;3375;PeerChannel Object;2025-04-02 19:19:03;Here are some of the stories we are covering from around the world:\n\nMyanmar Military Calls for Temporary Truce After Earthquake\n\nMyanmar’s military on Wednesday declared a 21-day cease-fire to support relief and reconstruction efforts in the wake of a devastating earthquake in the country; a day after it fired on a Chinese Red Cross convoy trying to deliver food and medicine to desperate survivors.\n\nIsrael Takes New Territory in Gaza; Squeezing Hamas\n\nPrime Minister Benjamin Netanyahu announced that Israel had seized a ribbon of territory in the Gaza Strip hours after his government laid out plans to seize large parts of the enclave.\n\nAngola Rail Line Offers Clues to Trump’s Africa Policy\n\nThe $4 billion project was the Biden administration’s signature initiative in Africa. Early signs are that the Trump team supports it; too; for mineral access if nothing else.\n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityBold'; 'offset': 0; 'length': 67}; {'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 59; 'url': 'https://nyti.ms/4cbU6FA'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 59}; {'_': 'MessageEntityTextUrl'; 'offset': 404; 'length': 51; 'url': 'https://nyti.ms/42svNQv'}; {'_': 'MessageEntityBold'; 'offset': 404; 'length': 51}; {'_': 'MessageEntityTextUrl'; 'offset': 644; 'length': 54; 'url': 'https://nyti.ms/4lexsk4'}; {'_': 'MessageEntityBold'; 'offset': 644; 'length': 54}; {'_': 'MessageEntityMention'; 'offset': 877; 'length': 8}];11914;9;None;2025-04-02 19:19:23;None;None;MessageReactions Object;[];None;None;None;None
# Message;3374;PeerChannel Object;2025-04-01 18:39:58;Here are some of the stories we are covering from around the world:\n\nA Prison Death Highlights an L.G.B.T.Q. Crackdown in Russia\n\nThe Russian government has unleashed a wave of repression against L.G.B.T.Q. people; with the police raiding gay night clubs and investigators targeting people they suspect of being gay.\n\nU.N. Accuses Israel of Killing 15 Rescue Workers in Gaza\n\nThe United Nations said Israeli forces killed the people as they were trying to aid injured civilians; then buried them in a mass grave. Israel said nine of the 15 dead were Palestinian militants.\n\nIceland Volcano Eruption Threatens Town\n\nA volcano in southwestern Iceland erupted on Tuesday; endangering the town of Grindavik and prompting the closure of the popular Blue Lagoon tourist destination.\n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityBold'; 'offset': 0; 'length': 67}; {'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 59; 'url': 'https://nyti.ms/4l9nctk'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 59}; {'_': 'MessageEntityTextUrl'; 'offset': 318; 'length': 56; 'url': 'https://nyti.ms/3DRJkb8'}; {'_': 'MessageEntityBold'; 'offset': 318; 'length': 56}; {'_': 'MessageEntityTextUrl'; 'offset': 574; 'length': 39; 'url': 'https://nyti.ms/4ljWZsn'}; {'_': 'MessageEntityBold'; 'offset': 574; 'length': 39}; {'_': 'MessageEntityMention'; 'offset': 778; 'length': 8}];15012;25;None;2025-04-01 18:40:49;None;None;MessageReactions Object;[];None;None;None;None
# Message;3373;PeerChannel Object;2025-03-31 19:59:24;Here are some of the stories we are covering from around the world:\n\nA NATO Plane’s Busy Duty: Tracking (and Dodging) Russia in the Baltic Sea\n\nThe assignment was part of a new program aimed at suspected Russian sabotage. None has occurred since NATO began patrols. Never fully tranquil; the Baltic Sea; with a coastline heavily militarized by Northern European and Russian navies; has become an increasingly tense theater in the conflict between Moscow and the West.\n\nThey Found Love at a Construction Site; Then Were Trapped Beneath It\n\nThe Bangkok building razed by Friday’s quake employed men and women who had found love at work. Despite glimmers of hope; many were still beneath the rubble.\n\nZimbabwe’s Leader Faces Call for Removal From Within His Own Party\n\nNearly eight years after the coup that brought him to power; President Emmerson Mnangagwa is under threat from opponents within his governing ZANU-PF party; who have urged mass protests.\n\nRead more\n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityBold'; 'offset': 0; 'length': 67}; {'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 73; 'url': 'https://nyti.ms/4jblp5c'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 73}; {'_': 'MessageEntityTextUrl'; 'offset': 469; 'length': 68; 'url': 'https://nyti.ms/4c98Yoa'}; {'_': 'MessageEntityBold'; 'offset': 469; 'length': 68}; {'_': 'MessageEntityTextUrl'; 'offset': 698; 'length': 66; 'url': 'https://nyti.ms/4lbPkMy'}; {'_': 'MessageEntityBold'; 'offset': 698; 'length': 66}; {'_': 'MessageEntityTextUrl'; 'offset': 954; 'length': 9; 'url': 'https://nyti.ms/4jblp5c'}; {'_': 'MessageEntityBold'; 'offset': 954; 'length': 9}; {'_': 'MessageEntityMention'; 'offset': 965; 'length': 8}; {'_': 'MessageEntityBold'; 'offset': 965; 'length': 8}];16746;12;None;2025-03-31 19:59:35;None;None;MessageReactions Object;[];None;None;None;None
# Message;3372;PeerChannel Object;2025-03-28 19:23:00;Here are some of the stories we are covering from around the world:\n\nMajor Quake Batters Myanmar; High Toll Is Feared as Buildings Topple\n\nA powerful earthquake struck central Myanmar on Friday; gouging open roads; toppling century-old religious monuments and destroying multistory buildings as it shook a vast expanse of Southeast Asia and dealt another severe blow to a country that has been ripped apart by civil war.\n\nUkraine Stages New Push Into Russia; Officials and Experts Say\n\nIn recent days; the Ukrainian Army has staged a new cross-border push into the Belgorod region of Russia; according to Ukrainian officials; analysts of open-source intelligence and Russian military bloggers. The advance comes as cease-fire talks continue.\n\nVance Lands in Greenland; a Place That Doesn’t Want Him\n\nVice President JD Vance landed in Greenland on Friday afternoon as part of a contentious trip pushed by the Trump administration and angrily opposed by Greenlanders. \n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 68; 'url': 'https://nyti.ms/4l7BECf'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 68}; {'_': 'MessageEntityTextUrl'; 'offset': 422; 'length': 62; 'url': 'https://nyti.ms/4hR5wzO'}; {'_': 'MessageEntityBold'; 'offset': 422; 'length': 62}; {'_': 'MessageEntityTextUrl'; 'offset': 743; 'length': 55; 'url': 'https://nyti.ms/3XB5FAq'}; {'_': 'MessageEntityBold'; 'offset': 743; 'length': 55}; {'_': 'MessageEntityMention'; 'offset': 968; 'length': 8}];24373;19;None;2025-03-28 19:23:49;None;None;MessageReactions Object;[];None;None;None;None
# Message;3371;PeerChannel Object;2025-03-27 19:47:07;Here are some of the stories we are covering from around the world:\n\nDrones; Mines and Snipers: Ukraine’s Front Line Is a World Away from Peace Talks\n\nHunted by drones; stalked by snipers and surrounded by minefields; soldiers fighting in Ukraine can’t risk even a small lapse in concentration; and any talk about a lasting cease-fire still feels like a dangerous fantasy.\n\nAs Musk Makes Some Headway in India; He Is Also Suing Its Government\n\nElon Musk’s pursuit of business expansion in India through Tesla and Starlink is coming at the same time that his X platform is waging a fight with the government over free speech.\n\nSouth Sudan’s Vice President Has Been Placed Under House Arrest; Party Says\n\nSouth Sudan’s vice president; Riek Machar; has been placed under house arrest; according to his party; escalating tensions that the United Nations has warned are pushing the world’s youngest country to the brink of civil war.\n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 80; 'url': 'https://nyti.ms/3XvsUfa'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 80}; {'_': 'MessageEntityTextUrl'; 'offset': 374; 'length': 68; 'url': 'https://nyti.ms/4l6KX5e'}; {'_': 'MessageEntityBold'; 'offset': 374; 'length': 68}; {'_': 'MessageEntityTextUrl'; 'offset': 626; 'length': 75; 'url': 'https://nyti.ms/41L33Cm'}; {'_': 'MessageEntityBold'; 'offset': 626; 'length': 75}; {'_': 'MessageEntityMention'; 'offset': 930; 'length': 8}];23540;17;None;2025-03-27 19:47:48;None;None;MessageReactions Object;[];None;None;None;None
# Message;3370;PeerChannel Object;2025-03-26 19:32:46;Here are some of the stories we are covering from around the world:\n\nGazans Protest Against Hamas and War for a Second Day\n\nPalestinians in Gaza protested against the war for a second straight day on Wednesday and chanted slogans against Hamas. The demonstrations; a rare show of dissent; appeared to have spread; reflecting frustration at the breakdown of a cease-fire with Israel.\n\nJair Bolsonaro Ordered to Face Trial in Brazil for Attempting a Coup\n\nJair Bolsonaro; Brazil’s former president; will face trial on charges that he oversaw a vast scheme to cling to power after losing the 2022 elections; the country’s Supreme Court decided on Wednesday.\n\nWorld’s Largest ‘Baby Exporter’ Admits to Adoption Fraud\n\nSouth Korea admitted for the first time that in its rush to send children to American and European homes decades ago; its adoption agencies committed widespread malpractices; including falsifying documents​; to make them more adoptable​.\n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 53; 'url': 'https://nyti.ms/4hLOnaU'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 53}; {'_': 'MessageEntityTextUrl'; 'offset': 384; 'length': 68; 'url': 'https://nyti.ms/424GDuS'}; {'_': 'MessageEntityBold'; 'offset': 384; 'length': 68}; {'_': 'MessageEntityTextUrl'; 'offset': 656; 'length': 56; 'url': 'https://nyti.ms/425KEiI'}; {'_': 'MessageEntityBold'; 'offset': 656; 'length': 56}; {'_': 'MessageEntityMention'; 'offset': 953; 'length': 8}];23424;15;None;2025-03-26 19:33:23;None;None;MessageReactions Object;[];None;None;None;None
# Message;3369;PeerChannel Object;2025-03-25 18:46:01;Here are some of the stories we are covering from around the world:\n\nWhite House Says Russia and Ukraine Agree to Stop Fighting in Black Sea\n\nThe White House said on Tuesday that Ukraine and Russia had agreed to cease fighting in the Black Sea and to hash out the details for halting strikes on energy facilities. It would be the first significant step toward the full cease-fire the Trump administration had been pushing; but it would still fall short of that goal.\n\nMob Descends on a Comedy Club After a Comic Jokes About a Politician\n\nPrime Minister Narendra Modi has said criticism is “the soul” of Indian democracy. But his allies unleashed vigilantes after a comic who called a politician a “traitor.”\n\nNow Europe Knows What Trump’s Team Calls It Behind Its Back: ‘Pathetic’\n\nTrump administration officials have demanded more European military spending and questioned the continent’s values. Leaked messages; carried out on the messaging app Signal; show the depth of the rift.\n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 71; 'url': 'https://nyti.ms/4iIAT0S'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 71}; {'_': 'MessageEntityTextUrl'; 'offset': 468; 'length': 68; 'url': 'https://nyti.ms/4c4q9Yc'}; {'_': 'MessageEntityBold'; 'offset': 468; 'length': 68}; {'_': 'MessageEntityTextUrl'; 'offset': 709; 'length': 71; 'url': 'https://nyti.ms/4l34Vhs'}; {'_': 'MessageEntityBold'; 'offset': 709; 'length': 71}; {'_': 'MessageEntityMention'; 'offset': 985; 'length': 8}];23113;15;None;2025-03-25 18:46:06;None;None;MessageReactions Object;[];None;None;None;None
# Message;3368;PeerChannel Object;2025-03-24 19:08:03;Here are some of the stories we are covering from around the world:\n\nSudan’s Military Sweeps Across Capital; Hoping to Turn the War\n\nA New York Times reporter and photographer were the first Western journalists to visit central Khartoum since the civil war broke out in Sudan two years ago. The scale of how much has been lost was inescapable.\n\nTurkey Ousts and Jails Istanbul Mayor; Who Was Expected to Run for President\n\nThe mayor of Istanbul; Ekrem Imamoglu; was jailed pending his trial on corruption charges and removed from office on Sunday; hobbling a potential contender in Turkey’s next presidential election and the top rival of President Recep Tayyip Erdogan.\n\nA War Within the War: Ukraine’s Ill Children\n\nIn three years of full-scale war; Ukrainian families of children with long-term illnesses have had to overcome countless challenges.\n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 62; 'url': 'https://nyti.ms/4j2bqPP'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 62}; {'_': 'MessageEntityTextUrl'; 'offset': 345; 'length': 76; 'url': 'https://nyti.ms/4iK3T8r'}; {'_': 'MessageEntityBold'; 'offset': 345; 'length': 76}; {'_': 'MessageEntityTextUrl'; 'offset': 672; 'length': 44; 'url': 'https://nyti.ms/4l3z0NZ'}; {'_': 'MessageEntityBold'; 'offset': 672; 'length': 44}; {'_': 'MessageEntityMention'; 'offset': 852; 'length': 8}];24213;14;None;2025-03-24 19:09:54;None;None;MessageReactions Object;[];None;None;None;None
# Message;3367;PeerChannel Object;2025-03-21 19:30:57;Here are some of the stories we are covering from around the world:\n\nWhat We Know About the Closure of Heathrow Airport\n\nHeathrow Airport in London was closed for most of Friday after it lost power because of a nearby fire; shutting down one of the world’s busiest air hubs and caused worldwide travel disruptions.\n\nRussian Energy Sites Burn as Kyiv and Moscow Trade Blame\n\nAs Ukraine and Russia prepare for talks that would place a temporary halt on strikes on energy infrastructure; each side has continued to accuse the other of fresh attacks on the power grid; underscoring the deep mistrust between them.\n\nSudan’s Military Retakes Presidential Palace in Devastated Capital\n\nTwo years into a civil war; Sudanese military forces recaptured the presidential palace in Khartoum; routing a paramilitary foe. Civilians have been trapped in the middle in a city with an apocalyptic air.\n\n@nytimes;False;False;False;False;True;False;False;True;False;False;False;False;False;None;None;None;None;None;None;None;MessageMediaPhoto Object;None;[{'_': 'MessageEntityTextUrl'; 'offset': 69; 'length': 50; 'url': 'https://nyti.ms/4kZlPxw'}; {'_': 'MessageEntityBold'; 'offset': 69; 'length': 50}; {'_': 'MessageEntityTextUrl'; 'offset': 316; 'length': 56; 'url': 'https://nyti.ms/4kH0kBr'}; {'_': 'MessageEntityBold'; 'offset': 316; 'length': 56}; {'_': 'MessageEntityTextUrl'; 'offset': 611; 'length': 66; 'url': 'https://nyti.ms/4iPOR0K'}; {'_': 'MessageEntityBold'; 'offset': 611; 'length': 66}; {'_': 'MessageEntityMention'; 'offset': 886; 'length': 8}];30652;25;None;2025-03-21 19:31:30;None;None;MessageReactions Object;[];None;None;None;None
